# %%
import scanpy as sc
import pandas as pd

# %%
# %%time
f = '/u/home/f/f7xiesnm/project-zipursky/v1-bb/v1/data/allen_dev_v1/DevVIS_multiome_snRNA_processed.h5ad'
adata = sc.read(f)
adata
# Out:
# CPU times: user 2.7 s, sys: 8.09 s, total: 10.8 s
# Wall time: 1min 18s
# AnnData object with n_obs × n_vars = 200061 × 32285
#     obs: 'Unnamed: 0', 'subcluster_id', 'subcluster_label', 'cluster_label', 'subclass_label', 'class_label', 'subcluster_prob', 'cluster_probability', 'subclass_probability', 'class_probability', 'library_prep', 'roi', 'sex', 'donor_name', 'age_label', 'cellNames'

# %%
adata.obs.age_label
# Out:
# AAACAGCCAATTAAGG-L8XR_210909_02_G08-1131257171    P11
# AAACAGCCAGCAACAG-L8XR_210909_02_G08-1131257171    P11
# AAACATGCAAGGGTTG-L8XR_210909_02_G08-1131257171    P11
# AAACATGCATACTCCT-L8XR_210909_02_G08-1131257171    P11
# AAACCAACACCAGCAT-L8XR_210909_02_G08-1131257171    P11
#                                                  ...
# TTTGTGTTCTCAATGA-L8XR_220721_02_D06-1196254077    P58
# TTTGTGTTCTTAATGG-L8XR_220721_02_D06-1196254077    P58
# TTTGTTGGTATACTGG-L8XR_220721_02_D06-1196254077    P58
# TTTGTTGGTGGGAACA-L8XR_220721_02_D06-1196254077    P58
# TTTGTTGGTTTCGCGC-L8XR_220721_02_D06-1196254077    P58
# Name: age_label, Length: 200061, dtype: category
# Categories (14, object): ['E15.5', 'E16', 'E17', 'E18', ..., 'P11', 'P14', 'P56', 'P58']

# %%
adata.obs['age_label'].value_counts(sort=False)
# Out:
# E15.5     3138
# E16       5921
# E17      12624
# E18       5647
# P0       40617
# P2       10139
# P4       11612
# P5       13105
# P8        6298
# P9        5267
# P11       5493
# P14      38580
# P56      35370
# P58       6250
# Name: age_label, dtype: int64

# %%
adata.obs['subclass_label'].value_counts() # sort=False)
# Out:
# L4/5 IT CTX Glut         22956
# L2/3 IT CTX Glut         22705
# L6 CT CTX Glut           19759
# IMN IT                   18929
# Astro-TE NN              13766
# L5 IT CTX Glut            8951
# Pvalb Gaba                8565
# L5 ET CTX Glut            8166
# L6 IT CTX Glut            8072
# OPC NN                    7562
# IMN nonIT                 6804
# Sst Gaba                  6080
# Glioblast                 5420
# Microglia NN              5014
# Oligo NN                  4615
# L6b/CT ENT Glut           3790
# Endo NN                   3077
# L5 NP CTX Glut            3054
# VLMC NN                   2626
# Vip Gaba                  2519
# MGE GABA                  2469
# CGE GABA                  2206
# Lamp5 Gaba                1711
# L6b CTX Glut              1465
# RG                        1289
# ABC NN                    1211
# CLA-EPd-CTX Car3 Glut     1089
# IP nonIT                  1005
# IP IT                      991
# NEC                        933
# ...

# %%
all_it_subclasses = [
    'L2/3 IT CTX Glut',
    'L4/5 IT CTX Glut',
    'L5 IT CTX Glut',
    'L6 IT CTX Glut',
]
adatasub = adata[adata.obs['subclass_label'].isin(all_it_subclasses)].copy()
adatasub
# Out:
# AnnData object with n_obs × n_vars = 62684 × 32285
#     obs: 'Unnamed: 0', 'subcluster_id', 'subcluster_label', 'cluster_label', 'subclass_label', 'class_label', 'subcluster_prob', 'cluster_probability', 'subclass_probability', 'class_probability', 'library_prep', 'roi', 'sex', 'donor_name', 'age_label', 'cellNames'

# %%
adatasub.obs['age_label'].value_counts(sort=False)
# Out:
# E15.5       57
# E16         66
# E17        580
# E18        521
# P0        6086
# P2        2614
# P4        4216
# P5        5515
# P8        2980
# P9        3458
# P11       2018
# P14      14609
# P56      16153
# P58       3811
# Name: age_label, dtype: int64

# %%
adatasub = adata[adata.obs['subclass_label'] == 'L2/3 IT CTX Glut'].copy()
adatasub
# Out:
# AnnData object with n_obs × n_vars = 22705 × 32285
#     obs: 'Unnamed: 0', 'subcluster_id', 'subcluster_label', 'cluster_label', 'subclass_label', 'class_label', 'subcluster_prob', 'cluster_probability', 'subclass_probability', 'class_probability', 'library_prep', 'roi', 'sex', 'donor_name', 'age_label', 'cellNames'

# %%
adatasub.obs['age_label'].value_counts(sort=False)
# Out:
# E15.5       2
# E17        18
# E18        23
# P0        748
# P2        856
# P4       1722
# P5       2395
# P8       1305
# P9       1324
# P11       738
# P14      5546
# P56      6364
# P58      1664
# Name: age_label, dtype: int64

# %%
adatasub = adata[adata.obs['subclass_label'] == 'Pvalb Gaba'].copy()
adatasub
# Out:
# AnnData object with n_obs × n_vars = 8565 × 32285
#     obs: 'Unnamed: 0', 'subcluster_id', 'subcluster_label', 'cluster_label', 'subclass_label', 'class_label', 'subcluster_prob', 'cluster_probability', 'subclass_probability', 'class_probability', 'library_prep', 'roi', 'sex', 'donor_name', 'age_label', 'cellNames'

# %%
adatasub.obs['age_label'].value_counts(sort=False)
# Out:
# E15.5      71
# E16       106
# E17       407
# E18       231
# P0       1718
# P2        645
# P4        794
# P5        782
# P8        270
# P9        166
# P11       179
# P14      1378
# P56      1540
# P58       278
# Name: age_label, dtype: int64
