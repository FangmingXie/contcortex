# %% [markdown]
# # setting up

# %%
import os
import numpy as np
import pandas as pd
from scipy.stats import zscore
from scipy import sparse
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

import scanpy as sc

# %%
from SingleCellArchetype.main import SCA
from SingleCellArchetype.utils import plot_archetype

# %% [markdown]
# # Load data

# %%
# %%time
f_anndata_in  = "../../data/v1_multiome/run_sca/multiome_l23_p21_hvg.h5ad"
adata_hvg = sc.read(f_anndata_in)
adata_hvg
# Out:
# CPU times: user 162 ms, sys: 350 ms, total: 512 ms
# Wall time: 2.06 s
# AnnData object with n_obs × n_vars = 2213 × 4420
#     obs: 'Age', 'Doublet', 'Doublet Score', 'n_counts', 'n_genes', 'percent_mito', 'sample', 'Type', 'Subclass', 'Class', 'Sample', 'total_counts', 'pct_counts_mt', 'n_genes_by_counts', 'total_counts_mt', 'Doublet?', 'Study', 'Type_leiden', 'time', 'cond'
#     var: 'feature_types'
#     layers: 'lognorm', 'norm', 'zlognorm'

# %%
genes_hvg = adata_hvg.var.index.values

# %% [markdown]
# # Run SingleCellArchetype with different controls
#
# - First, we can infer archetypes using the original data.
# - To assess the **stability** of archetypal inference, we downsample cells (or genes) and repeat the inference.
# - To assess the **statistical significance of the archetypal fit**, we **shuffle the data** and compare the shuffled results with data. The effect can be directly visualized, and quantified using t-ratio test.
# - To assess the **significance of the transcriptomic continuum**, we shuffle the data **locally within each cell type (or cluster)**. The effect can be directly visualzed (and later quantified).

# %%
types = [0]*len(adata_hvg)
norm_mat = np.array(adata_hvg.layers['lognorm'])
sca = SCA(norm_mat, types)

# %%
ndim = 2
noc = 3
sca.setup_feature_matrix(method='data')
xp, aa = sca.proj_and_pcha(ndim, noc)

nrepeats = 3
aa_boots = sca.bootstrap_proj_pcha(ndim, noc, nrepeats=nrepeats)
# Out:
# use data

# %%
# gshuff
sca.setup_feature_matrix(method='gshuff')
xp_gshuff, aa_gshuff = sca.proj_and_pcha(ndim, noc)
aa_gshuff_boots = sca.bootstrap_proj_pcha(ndim, noc, nrepeats=nrepeats)
# Out:
# use shuffled data

# %%
# tshuff 
sca.setup_feature_matrix(method='tshuff')
xp_tshuff, aa_tshuff = sca.proj_and_pcha(ndim, noc)
aa_tshuff_boots = sca.bootstrap_proj_pcha(ndim, noc, nrepeats=nrepeats)
# Out:
# use per-type shuffled data

# %% [markdown]
# # plot

# %%
types_colorvec = np.char.add('C', sca.types_idx.astype(str))

# %%
# plot
fig, axs = plt.subplots(1,3,figsize=(8*3,6))
ax = axs[0]
ax.scatter(xp[:,0], xp[:,1], c=types_colorvec, s=2)
plot_archetype(ax, aa, fmt='-o', color='k', zorder=2)
for i in range(nrepeats):
    plot_archetype(ax, aa_boots[i], fmt='--', color='gray', zorder=0)
ax.set_title('Data\n(single cells colored by type)')
    
ax = axs[1]
ax.set_title('Shuffled')
ax.scatter(xp_gshuff[:,0], xp_gshuff[:,1], c=types_colorvec, s=2)
plot_archetype(ax, aa_gshuff, fmt='-o', color='k', zorder=2)
for i in range(nrepeats):
    plot_archetype(ax, aa_gshuff_boots[i], fmt='--', color='gray', zorder=0)

ax = axs[2]
ax.set_title('Shuffled within each type')
ax.scatter(xp_tshuff[:,0], xp_tshuff[:,1], c=types_colorvec, s=2)
plot_archetype(ax, aa_tshuff, fmt='-o', color='k', zorder=2)
for i in range(nrepeats):
    plot_archetype(ax, aa_tshuff_boots[i], fmt='--', color='gray', zorder=0)

for i in range(3):
    ax = axs[i]
    ax.set_xlabel('PC1')
    ax.set_ylabel('PC2')
    ax.set_aspect('equal')
    sns.despine(ax=ax)
    ax.grid(False)
    
plt.show()

# %% [markdown]
# # quantify t-ratio
#
# - for 2-dimensional data only

# %%
t_ratio, t_ratio_shuffs, pval = sca.t_ratio_test(ndim, noc, nrepeats=20)
print(f'p-value: {pval}')
# Out:
# use data
# use shuffled data
# use shuffled data
# use shuffled data
# use shuffled data
# use shuffled data
# use shuffled data
# use shuffled data
# use shuffled data
# use shuffled data
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/.conda/envs/napari/lib/python3.9/site-packages/py_pcha/PCHA.py:153, in PCHA(X, noc, I, U, delta, verbose, conv_crit, maxiter)
#     152 try:
# --> 153     i = furthest_sum(X[:, I], noc, [int(np.ceil(len(I) * np.random.rand()))])
#     154 except IndexError:
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/py_pcha/furthest_sum.py:39, in furthest_sum(K, noc, i, exclude)
#      38 index[exclude] = 0
# ---> 39 index[i] = -1
#      40 ind_t = i
#
# IndexError: index 2213 is out of bounds for axis 0 with size 2213
#
# During handling of the above exception, another exception occurred:
#
# InitializationException                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t_ratio, t_ratio_shuffs, pval = sca.t_ratio_test(ndim, noc, nrepeats=20)
#       2 print(f'p-value: {pval}')
#
# File /u/project/zipursky/f7xiesnm/v1-bb/v1/SingleCellArchetype/src/SingleCellArchetype/main.py:125, in SCA.t_ratio_test(self, ndim, noc, nrepeats, **kwargs)
#     123 for i in range(nrepeats):
#     124     self.setup_feature_matrix(method='gshuff')
# --> 125     xp_shuff, aa_shuff = self.proj_and_pcha(ndim, noc)
#     126     t_ratio_shuff = get_t_ratio(xp_shuff, aa_shuff)
#     127     t_ratios_shuff.append(t_ratio_shuff)
#
# File /u/project/zipursky/f7xiesnm/v1-bb/v1/SingleCellArchetype/src/SingleCellArchetype/main.py:70, in SCA.proj_and_pcha(self, ndim, noc, **kwargs)
#      67 """
#      68 """
#      69 xp = proj(self.xf, ndim)
# ---> 70 aa = pcha(xp.T, noc=noc, **kwargs)
#      72 self.xp = xp
#      73 self.aa = aa
#
# File /u/project/zipursky/f7xiesnm/v1-bb/v1/SingleCellArchetype/src/SingleCellArchetype/utils.py:61, in pcha(X, noc, delta, **kwargs)
#      58 def pcha(X, noc=3, delta=0, **kwargs):
#      59     """
#      60     """
# ---> 61     XC, S, C, SSE, varexpl = PCHA(X, noc=noc, delta=delta, **kwargs)
#      62     XC = np.array(XC)
#      63     XC = XC[:,np.argsort(XC[0])] # assign an order according to x-axis
#
# File ~/.conda/envs/napari/lib/python3.9/site-packages/py_pcha/PCHA.py:156, in PCHA(X, noc, I, U, delta, verbose, conv_crit, maxiter)
#     154 except IndexError:
#     155     class InitializationException(Exception): pass
# --> 156     raise InitializationException("Initialization does not converge. Too few examples in dataset.")
#     158 j = range(noc)
#     159 C = csr_matrix((np.ones(len(i)), (i, j)), shape=(len(I), noc)).todense()
#
# InitializationException: Initialization does not converge. Too few examples in dataset.

# %%
fig, ax = plt.subplots()
ax.axvline(t_ratio, color='r', label='data')
sns.histplot(t_ratio_shuffs, ax=ax, stat='density', label='shuffled')
ax.set_xlabel('t-ratio')
ax.legend()
sns.despine(ax=ax)
plt.show()

# %% [markdown]
# # quantify stability

# %%
from sklearn.metrics import pairwise_distances

# %%
def get_relative_variation(aa_list):
    """
    """
    
    aa_avg = np.mean(aa_list, axis=0).T
    ref = np.mean(pairwise_distances(aa_avg))

    aa_std = np.std(aa_list, axis=0).T
    epsilon = np.mean(np.sqrt(np.sum(np.power(aa_std,2), axis=1)))
    
    return epsilon/ref

# %%
var_data   = get_relative_variation(aa_boots)
var_gshuff = get_relative_variation(aa_gshuff_boots)

# %%
fig, ax = plt.subplots(figsize=(3,6))
ax.bar(np.arange(2), [var_data, var_gshuff])
ax.set_xticks(np.arange(2))
ax.set_xticklabels(['data', 'shuffled'], rotation=90)
ax.set_ylabel('Archetype variation')
plt.show()
